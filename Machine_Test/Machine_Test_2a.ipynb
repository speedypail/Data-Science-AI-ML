# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
df1=pd.read_excel('Restaruent.xlsx',sheet_name='customer')
df2=pd.read_excel('Restaruent.xlsx',sheet_name='restaurant')
df3=pd.read_excel('Restaruent.xlsx',sheet_name='orders')
print(df1)
# Out:
#   CustomerID    Name  Age  Gender        City MembershipType
# 0       C001   Rahul   24    Male       Kochi         Silver
# 1       C002  Anjali   31  Female  Trivandrum           Gold
# 2       C003   Akash   28    Male       Kochi         Silver
# 3       C004   Meera   22  Female     Calicut       Platinum
# 4       C005   Arjun   35    Male  Trivandrum           Gold
# 5       C006    Neha   27  Female       Kochi         Silver
# 6       C007   Vivek   40    Male     Calicut       Platinum
# 7       C008   Aisha   26  Female       Kochi           Gold
# 8       C009  Nithin   33    Male  Trivandrum         Silver
# 9       C010    Diya   29  Female     Calicut           Gold
