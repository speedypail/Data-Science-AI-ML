# %%
import pandas as pd
data={
    'Hours Studied':[2,4,6,8,10],
    'Marks':[40,55,75,90,98]
}
df=pd.DataFrame(data)
print(df)
# Out:
#    Hours Studied  Marks
# 0              2     40
# 1              4     55
# 2              6     75
# 3              8     90
# 4             10     98

# %%
X=df[['Hours Studied']]
y=df['Marks']
print(X)
print('\n')
print(y)
# Out:
#    Hours Studied
# 0              2
# 1              4
# 2              6
# 3              8
# 4             10
#
#
# 0    40
# 1    55
# 2    75
# 3    90
# 4    98
# Name: Marks, dtype: int64

# %%
print('Data → Features → Model → Prediction')
# Out:
# Data → Features → Model → Prediction

# %%
new_student=[[5]]
print('New Student:', new_student)
# Out:
# New Student: [[5]]
