# %%
import pandas as pd
data={
    'Income':[25000,40000,50000,65000,80000],
    'Loan Approved':[0,0,1,1,1]
}
df=pd.DataFrame(data)
print(df)
# Out:
#    Income  Loan Approved
# 0   25000              0
# 1   40000              0
# 2   50000              1
# 3   65000              1
# 4   80000              1

# %%
X=df[['Income']]
y=df['Loan Approved']
print(X)
print('\n')
print(y)
# Out:
#    Income
# 0   25000
# 1   40000
# 2   50000
# 3   65000
# 4   80000
#
#
# 0    0
# 1    0
# 2    1
# 3    1
# 4    1
# Name: Loan Approved, dtype: int64

# %%
new_customer = [[60000]]
print('New Customer:',new_customer)
# Out:
# New Customer: [[60000]]

# %%
print('Prediction will be made using the trained model.')
# Out:
# Prediction will be made using the trained model.
