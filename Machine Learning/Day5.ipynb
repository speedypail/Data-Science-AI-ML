# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
data=pd.read_csv('employee_salary_dataset.csv')
print(data)
# Out:
#       experience_years  age  education_level  working_hours  \
# 0                    6   32                1             36
# 1                   19   52                3             45
# 2                   14   45                3             44
# 3                   10   38                2             47
# 4                    7   35                4             41
# ...                ...  ...              ...            ...
# 9995                11   50                2             54
# 9996                22   50                4             41
# 9997                16   45                2             41
# 9998                14   27                4             36
# 9999                 8   40                2             45
#
#       performance_score  projects_completed  salary
# 0                     1                   1   57743
# 1                     5                   0  107633
# 2                     7                  17  115431
# ...

# %%
df.head()
# Out:
#    experience_years  age  education_level  working_hours  performance_score  \
# 0                 6   32                1             36                  1
# 1                19   52                3             45                  5
# 2                14   45                3             44                  7
# 3                10   38                2             47                  1
# 4                 7   35                4             41                  8
#
#    projects_completed  salary
# 0                   1   57743
# 1                   0  107633
# 2                  17  115431
# 3                  17   85031
# 4                   7   97001

# %%
df.shape
# Out:
# (10000, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   experience_years    10000 non-null  int64
#  1   age                 10000 non-null  int64
#  2   education_level     10000 non-null  int64
#  3   working_hours       10000 non-null  int64
#  4   performance_score   10000 non-null  int64
#  5   projects_completed  10000 non-null  int64
#  6   salary              10000 non-null  int64
# dtypes: int64(7)
# memory usage: 547.0 KB

# %%
df.describe()
# Out:
#        experience_years           age  education_level  working_hours  \
# count      10000.000000  10000.000000     10000.000000    10000.00000
# mean          12.134100     37.391100         2.516400       44.55600
# std            7.233308      9.726778         1.117522        5.71968
# min            0.000000     21.000000         1.000000       35.00000
# 25%            6.000000     29.000000         2.000000       40.00000
# 50%           12.000000     37.000000         3.000000       45.00000
# 75%           18.000000     46.000000         4.000000       49.00000
# max           24.000000     54.000000         4.000000       54.00000
#
#        performance_score  projects_completed         salary
# count       10000.000000        10000.000000   10000.000000
# mean            5.568300            9.434300  100880.730800
# std             2.868407            5.756596   22502.540928
# min             1.000000            0.000000   34513.000000
# ...

# %%
plt.scatter(data['experience_years'],data['salary'])
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %%
X = data[['experience_years','age','education_level','working_hours','performance_score','projects_completed']]
y = data['salary']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=42,test_size=0.2)

# %%
model=LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X_test)
mean_squared_error(y_test,y_pred)
r2_score(y_test,y_pred)
# Out:
# 0.9337499553705981

# %%
new_employee = pd.DataFrame({
    "experience_years": [8],
    "age": [34],
    "education_level": [3],
    "working_hours": [45],
    "performance_score": [8],
    "projects_completed": [12]
})

predicted_salary = model.predict(new_employee)

print("\nPredicted Salary for New Employee:")
print("₹", predicted_salary[0])
# Out:
# Predicted Salary for New Employee:
# ₹ 103328.5263198948
