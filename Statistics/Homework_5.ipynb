# %%
from sklearn.preprocessing import MinMaxScaler
marks = [[35], [50], [65], [80], [300]]
print('The original marks is:\n',marks)
# Out:
# The original marks is:
#  [[35], [50], [65], [80], [300]]

# %%
print('The minimum marks is:',min(marks))
# Out:
# The minimum marks is: [35]

# %%
print('The maximum marks is:',max(marks))
# Out:
# The maximum marks is: [300]

# %%
print('The identified outliers in marks dataset is 300')
# Out:
# The identified outliers in marks dataset is 300

# %%
print("An outlier is an unusually high or low value that can distort the mean, increase the standard deviation and variance, affect statistical analysis, and reduce the accuracy of some machine learning models. Therefore, outliers should be identified and handled appropriately before analysis.")
# Out:
# An outlier is an unusually high or low value that can distort the mean, increase the standard deviation and variance, affect statistical analysis, and reduce the accuracy of some machine learning models. Therefore, outliers should be identified and handled appropriately before analysis.
