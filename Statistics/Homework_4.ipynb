# %%
purchases = [200, 220, 210, 205, 215, 1000]
print(f'The outliers in the purchase dataset is: {max(purchases)}')
print('The noise in the purchase dataset is 1000 since all other dataset lies betwwen 200 and 220 while 1000 is much larger datapoint')
# Out:
# The outliers in the purchase dataset is: 1000
# The noise in the purchase dataset is 1000 since all other dataset lies betwwen 200 and 220 while 1000 is much larger datapoint

# %%
sample = ["premium", "premium", "premium"]
print(sample)
print('The sample may create a sampling error because it contains only premium which can make bad decisions')
# Out:
# ['premium', 'premium', 'premium']
# The sample may create a sampling error because it contains only premium which can make bad decisions

# %%
advertisements = [10, 20, 30, 40]
sales = [100, 200, 300, 400]
print(advertisements)
print(sales)
print('No,A high correlation does not prove causation. It only shows that the variables move together. Other factors or coincidental relationships may also explain the pattern. Establishing causation typically requires controlled experiments or stronger evidence than correlation alone.')
# Out:
# [10, 20, 30, 40]
# [100, 200, 300, 400]
# No,A high correlation does not prove causation. It only shows that the variables move together. Other factors or coincidental relationships may also explain the pattern. Establishing causation typically requires controlled experiments or stronger evidence than correlation alone.

# %%
print('H₀ (Null Hypothesis): Customer spending has not changed.')
print('H₁ (Alternative Hypothesis): Customer spending has changed.')
# Out:
# H₀ (Null Hypothesis): Customer spending has not changed.
# H₁ (Alternative Hypothesis): Customer spending has changed.

# %%
p_value=0.08
alpha=0.05
if p_value<alpha:
    print('Reject H0')
else:
    print('Failed to Reject H0')
# Out:
# Failed to Reject H0
