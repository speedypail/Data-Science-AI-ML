# %%
from sklearn.preprocessing import MinMaxScaler
salaries = [[25000], [40000], [55000], [70000], [85000]]
scaler=MinMaxScaler()
normalized=scaler.fit_transform(salaries)
print('Normalized data:\n',normalized)
# Out:
# Normalized data:
#  [[0.  ]
#  [0.25]
#  [0.5 ]
#  [0.75]
#  [1.  ]]

# %%
print(min(normalized))
# Out:
# [0.]

# %%
print(max(normalized))
# Out:
# [1.]
