# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df1=pd.read_excel('seaborn.xlsx',sheet_name='Customers')
print(df1)
print('\n')
df2=pd.read_excel('seaborn.xlsx',sheet_name='Products')
print(df2)
print('\n')
df3=pd.read_excel('seaborn.xlsx',sheet_name='Orders')
print(df3)
# Out:
#      Customer_ID  Age  Gender       City
# 0              1   56  Female      Kochi
# 1              2   46    Male    Chennai
# 2              3   32  Female      Kochi
# 3              4   60    Male    Chennai
# 4              5   25    Male  Bangalore
# ..           ...  ...     ...        ...
# 195          196   49  Female  Hyderabad
# 196          197   49    Male    Chennai
# 197          198   41  Female    Chennai
# 198          199   58  Female  Hyderabad
# 199          200   29  Female      Kochi
#
# [200 rows x 4 columns]
#
#
#     Product_ID Product_Name     Category  Price
# 0            1    Product_1         Home   4692
# 1            2    Product_2       Sports    995
# 2            3    Product_3  Electronics   3646
# 3            4    Product_4     Clothing    951
# 4            5    Product_5     Clothing   1787
# 5            6    Product_6  Electronics   2031
# 6            7    Product_7         Home   3846
# 7            8    Product_8     Clothing   2527
# ...

# %%
# Question 1
print('The first 5 rows from customer sheet is:\n',df1.head())
print('\n')
print('The first 5 rows from product sheet is:\n',df2.head())
print('\n')
print('The first 5 rows from orders sheet is:\n',df3.head())
# Out:
# The first 5 rows from customer sheet is:
#     Customer_ID  Age  Gender       City
# 0            1   56  Female      Kochi
# 1            2   46    Male    Chennai
# 2            3   32  Female      Kochi
# 3            4   60    Male    Chennai
# 4            5   25    Male  Bangalore
#
#
# The first 5 rows from product sheet is:
#     Product_ID Product_Name     Category  Price
# 0           1    Product_1         Home   4692
# 1           2    Product_2       Sports    995
# 2           3    Product_3  Electronics   3646
# 3           4    Product_4     Clothing    951
# 4           5    Product_5     Clothing   1787
#
#
# The first 5 rows from orders sheet is:
#     Order_ID  Customer_ID  Product_ID  Quantity  Discount  Rating Order_Date
# 0         1          105          26         1      0.21     2.4 2023-09-30
# 1         2          135           7         4      0.16     2.6 2023-12-18
# 2         3          196          14         4      0.02     NaN 2023-05-24
# ...

# %%
# Question 2
import pandas as pd

# Read the Excel file
file = "seaborn.xlsx"

# Read all sheets
datasets = pd.read_excel(file, sheet_name=None)

for name, df in datasets.items():
    print(f"\n{name}")

    # Numeric columns
    numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns.tolist()

    # Categorical columns
    categorical_cols = df.select_dtypes(include=['object']).columns.tolist()

    # Date/Time columns
    datetime_cols = df.select_dtypes(include=['datetime64']).columns.tolist()

    print("Numeric Columns:", numeric_cols)
    print("Categorical Columns:", categorical_cols)
    print("Date/Time Columns:", datetime_cols)
# Out:
# Customers
# Numeric Columns: ['Customer_ID', 'Age']
# Categorical Columns: ['Gender', 'City']
# Date/Time Columns: []
#
# Products
# Numeric Columns: ['Product_ID', 'Price']
# Categorical Columns: ['Product_Name', 'Category']
# Date/Time Columns: []
#
# Orders
# Numeric Columns: ['Order_ID', 'Customer_ID', 'Product_ID', 'Quantity', 'Discount', 'Rating']
# Categorical Columns: []
# Date/Time Columns: ['Order_Date']
