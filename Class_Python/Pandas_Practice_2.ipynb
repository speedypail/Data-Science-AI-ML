# %%
import pandas as pd
data = {'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva', 'Frank'],
        'Age': [24, 27, 22, 32, 29, 25],
        'Marks': [85, 90, 78, 88, 92, 75]}
df = pd.DataFrame(data)
print(df.head()) # Returns first 5 rows from the element
# Out:
#       Name  Age  Marks
# 0    Alice   24     85
# 1      Bob   27     90
# 2  Charlie   22     78
# 3    David   32     88
# 4      Eva   29     92

# %%
import pandas as pd
data = {'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva', 'Frank'],
        'Age': [24, 27, 22, 32, 29, 25],
        'Marks': [85, 90, 78, 88, 92, 75]}
df = pd.DataFrame(data)
print(df.tail()) # Returns lat 5 rows from the element
# Out:
#       Name  Age  Marks
# 1      Bob   27     90
# 2  Charlie   22     78
# 3    David   32     88
# 4      Eva   29     92
# 5    Frank   25     75

# %%
import pandas as pd
data = {'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva', 'Frank'],
        'Age': [24, 27, 22, 32, 29, 25],
        'Marks': [85, 90, 78, 88, 92, 75]}
df = pd.DataFrame(data)
df.info() # It gives the techncial infromation of the data like what is the data type, how much memory is being used and so on
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    6 non-null      object
#  1   Age     6 non-null      int64
#  2   Marks   6 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 272.0+ bytes

# %%
import pandas as pd
data = {'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva', 'Frank'],
        'Age': [24, 27, 22, 32, 29, 25],
        'Marks': [85, 90, 78, 88, 92, 75]}
df = pd.DataFrame(data)
print(df.describe()) # Describe gives the statastical infromation about the data
# Out:
#              Age      Marks
# count   6.000000   6.000000
# mean   26.500000  84.666667
# std     3.619392   6.801961
# min    22.000000  75.000000
# 25%    24.250000  79.750000
# 50%    26.000000  86.500000
# 75%    28.500000  89.500000
# max    32.000000  92.000000

# %%
import pandas as pd
data = {'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva', 'Frank'],
        'Age': [24, 27, 22, 32, 29, 25],
        'Marks': [85, 90, 78, 88, 92, 75]}
df = pd.DataFrame(data)
print(df.shape)
# Out:
# (6, 3)

# %%
import pandas as pd
data = {'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva', 'Frank'],
        'Age': [24, 27, 22, 32, 29, 25],
        'Marks': [85, 90, 78, 88, 92, 75]}
df = pd.DataFrame(data)
print(df.columns)
# Out:
# Index(['Name', 'Age', 'Marks'], dtype='object')

# %%
import pandas as pd
data = {'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva', 'Frank'],
        'Age': [24, 27, 22, 32, 29, 25],
        'Marks': [85, 90, 78, 88, 92, 75]}
df = pd.DataFrame(data)
print(df.dtypes)
# Out:
# Name     object
# Age       int64
# Marks     int64
# dtype: object

# %%
import pandas as pd

df = pd.DataFrame({
    "Name": ["Asha", "Ravi", "Kiran", "Meera", "Vikram"],
    "Age": [24, 30, 28, 26, 32],
    "Gender": ["Female", "Male", "Male", "Female", "Male"],
    "Department": ["HR", "IT", "IT", "Finance", "HR"]
})

df["Gender"] = df["Gender"].astype("category")

print(df)
print(df.dtypes)
# Out:
#      Name  Age  Gender Department
# 0    Asha   24  Female         HR
# 1    Ravi   30    Male         IT
# 2   Kiran   28    Male         IT
# 3   Meera   26  Female    Finance
# 4  Vikram   32    Male         HR
# Name            object
# Age              int64
# Gender        category
# Department      object
# dtype: object

# %%
import pandas as pd

data = {"Name": ["Asha", "Ravi", "Kiran"]}
df = pd.DataFrame(data, index=["row1", "row2", "row3"])
print(df)
# Out:
#        Name
# row1   Asha
# row2   Ravi
# row3  Kiran

# %%
import pandas as pd

arrays = [
    ["India", "India", "USA", "USA"],
    ["2023", "2024", "2023", "2024"]
]

index = pd.MultiIndex.from_arrays(arrays, names=("Country", "Year"))

df = pd.DataFrame({"Sales": [100, 120, 90, 110]}, index=index)
print(df)
# Out:
#               Sales
# Country Year
# India   2023    100
#         2024    120
# USA     2023     90
#         2024    110

# %%
import pandas as pd
data = {'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva', 'Frank'],
        'Age': [24, 27, None, 32, 29, 25],
        'Marks': [85, 90, 78, 88, 92, 75]}
df = pd.DataFrame(data)
print(df.isnull())
print(df.isnull().sum())
# Out:
#     Name    Age  Marks
# 0  False  False  False
# 1  False  False  False
# 2  False   True  False
# 3  False  False  False
# 4  False  False  False
# 5  False  False  False
# Name     0
# Age      1
# Marks    0
# dtype: int64
