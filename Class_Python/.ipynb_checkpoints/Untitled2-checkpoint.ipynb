# %%
import pandas as pd
df=pd.read_csv('sample_dataset.csv')
print(df)
dataframe=pd.DataFrame(df)
print(dataframe)
# Out:
#      EmployeeID    Name  Gender Department        City   Age    Salary  \
# 0        1254.0    Arun    Male      SALES  TRIVANDRUM  24.0  60759.29
# 1        1427.0  VISHNU  FEMALE      SALES     chennai  29.0  66754.41
# 2        1497.0  VISHNU  FEMALE    Finance       Kochi  35.0  75372.82
# 3        1040.0  VISHNU  FEMALE      SALES  TRIVANDRUM  36.0  65266.16
# 4        1290.0   MEERA    MALE  Marketing  TRIVANDRUM  25.0  48285.07
# ..          ...     ...     ...        ...         ...   ...       ...
# 515      1456.0  VISHNU  female         IT  TRIVANDRUM  22.0  81453.74
# 516      1482.0    JOHN  FEMALE    Finance   Bangalore  32.0  43073.55
# 517      1416.0   MEERA    Male         hr     MADURAI  33.0  34260.46
# 518      1085.0    JOHN    MALE    Finance     MADURAI  31.0  32016.82
# 519      1419.0    JOHN    MALE      SALES       Kochi  24.0  86503.54
#
#      Experience  PerformanceScore    Status
# 0           7.0               2.9       NaN
# ...

# %%
print(dataframe.head(10)) # To display first 5 rows
# Out:
#    EmployeeID    Name  Gender Department        City   Age    Salary  \
# 0      1254.0    Arun    Male      SALES  TRIVANDRUM  24.0  60759.29
# 1      1427.0  VISHNU  FEMALE      SALES     chennai  29.0  66754.41
# 2      1497.0  VISHNU  FEMALE    Finance       Kochi  35.0  75372.82
# 3      1040.0  VISHNU  FEMALE      SALES  TRIVANDRUM  36.0  65266.16
# 4      1290.0   MEERA    MALE  Marketing  TRIVANDRUM  25.0  48285.07
# 5      1308.0   rahul    Male    Finance     chennai  27.0  81135.83
# 6      1166.0    Arun  female    Finance       Kochi  27.0  87868.60
# 7      1247.0    Arun  female      SALES     MADURAI  22.0  40492.89
# 8      1217.0  VISHNU  female      SALES  TRIVANDRUM  32.0  72614.57
# 9      1145.0   sneha  FEMALE         IT     chennai  22.0  75405.09
#
#    Experience  PerformanceScore    Status
# 0         7.0               2.9       NaN
# 1        12.0               3.1  inactive
# 2         7.0               3.7    Active
# ...

# %%
print(dataframe.tail()) # To print last 5 rows
# Out:
#      EmployeeID    Name  Gender Department        City   Age    Salary  \
# 515      1456.0  VISHNU  female         IT  TRIVANDRUM  22.0  81453.74
# 516      1482.0    JOHN  FEMALE    Finance   Bangalore  32.0  43073.55
# 517      1416.0   MEERA    Male         hr     MADURAI  33.0  34260.46
# 518      1085.0    JOHN    MALE    Finance     MADURAI  31.0  32016.82
# 519      1419.0    JOHN    MALE      SALES       Kochi  24.0  86503.54
#
#      Experience  PerformanceScore    Status
# 515         6.0               2.6  Inactive
# 516         1.0               4.5    ACTIVE
# 517        13.0               4.0  inactive
# 518         2.0               4.8    Active
# 519         8.0               3.3  inactive

# %%
print(dataframe.info()) # To display the information about the dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 520 entries, 0 to 519
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   EmployeeID        504 non-null    float64
#  1   Name              505 non-null    object
#  2   Gender            505 non-null    object
#  3   Department        505 non-null    object
#  4   City              505 non-null    object
#  5   Age               504 non-null    float64
#  6   Salary            504 non-null    float64
#  7   Experience        505 non-null    float64
#  8   PerformanceScore  504 non-null    float64
#  9   Status            503 non-null    object
# dtypes: float64(5), object(5)
# memory usage: 40.8+ KB
# None

# %%
print(df.describe()) # It geneartes statstical summaries like mean count,std,min and max
# Out:
#         EmployeeID         Age        Salary  Experience  PerformanceScore
# count   504.000000  504.000000    504.000000  505.000000        504.000000
# mean   1249.081349   30.261905  59022.386766    7.261386          3.781944
# std     144.045123    5.193556  16996.622793    4.040837          0.717802
# min    1001.000000   22.000000  30093.910000    1.000000          2.500000
# 25%    1123.750000   25.000000  45036.692500    4.000000          3.200000
# 50%    1249.500000   30.000000  59029.955000    7.000000          3.800000
# 75%    1372.250000   35.000000  73368.860000   11.000000          4.400000
# max    1500.000000   39.000000  89900.850000   14.000000          5.000000

# %%
print(dataframe.shape)
# Out:
# (520, 10)

# %%
print(dataframe.columns)
# Out:
# Index(['EmployeeID', 'Name', 'Gender', 'Department', 'City', 'Age', 'Salary',
#        'Experience', 'PerformanceScore', 'Status'],
#       dtype='object')

# %%
print(dataframe.dtypes)
# Out:
# EmployeeID          float64
# Name                 object
# Gender               object
# Department           object
# City                 object
# Age                 float64
# Salary              float64
# Experience          float64
# PerformanceScore    float64
# Status               object
# dtype: object

# %%
dataframe['Gender']=dataframe['Gender'].astype('category')
print(dataframe.dtypes)
# Out:
# EmployeeID           float64
# Name                  object
# Gender              category
# Department            object
# City                  object
# Age                  float64
# Salary               float64
# Experience           float64
# PerformanceScore     float64
# Status                object
# dtype: object

# %%
print(dataframe.isnull())
# Out:
#      EmployeeID   Name  Gender  Department   City    Age  Salary  Experience  \
# 0         False  False   False       False  False  False   False       False
# 1         False  False   False       False  False  False   False       False
# 2         False  False   False       False  False  False   False       False
# 3         False  False   False       False  False  False   False       False
# 4         False  False   False       False  False  False   False       False
# ..          ...    ...     ...         ...    ...    ...     ...         ...
# 515       False  False   False       False  False  False   False       False
# 516       False  False   False       False  False  False   False       False
# 517       False  False   False       False  False  False   False       False
# 518       False  False   False       False  False  False   False       False
# 519       False  False   False       False  False  False   False       False
#
#      PerformanceScore  Status
# ...

# %%
print(isnull.sum())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 print(isnull.sum())
#
# NameError: name 'isnull' is not defined
