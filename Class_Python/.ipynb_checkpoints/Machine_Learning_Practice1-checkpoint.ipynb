# %%
import pandas as pd

data = {
    "email_length": [120, 450, 180, 600],
    "spam": [0, 1, 0, 1]
}

df = pd.DataFrame(data)
print(df)
# Out:
#    email_length  spam
# 0           120     0
# 1           450     1
# 2           180     0
# 3           600     1

# %%
import pandas as pd

data = {
    "hours_studied": [2, 4, 6, 8],
    "marks": [40, 55, 75, 90]
}

df = pd.DataFrame(data)
print(df)
# Out:
#    hours_studied  marks
# 0              2     40
# 1              4     55
# 2              6     75
# 3              8     90

# %%
X = [[25000], [50000], [75000]]
y = [0, 1, 1]

model.fit(X, y)
prediction = model.predict([[60000]])
print(prediction)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       1 X = [[25000], [50000], [75000]]
#       2 y = [0, 1, 1]
# ----> 4 model.fit(X, y)
#       5 prediction = model.predict([[60000]])
#       6 print(prediction)
#
# NameError: name 'model' is not defined

# %%
from sklearn.linear_model import LinearRegression

X = [[1], [2], [3], [4]]
y = [2, 4, 6, 8]

model = LinearRegression()
model.fit(X, y)

prediction = model.predict([[5]])
print(prediction)
# Out:
# [10.]
