# %%
import matplotlib.pyplot as plt
fig = plt.figure()

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()

# %%
import matplotlib.pyplot as plt
plt.plot([1, 2, 3], [4, 5, 6])

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [10, 20, 25, 30]

plt.plot(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.xlabel("Time (s)")
plt.ylabel("Speed (m/s)")
plt.show()

# %%
import matplotlib.pyplot as plt
plt.title("Speed Over Time")
plt.xlabel("Time (s)")
plt.ylabel("Speed (m/s)")
plt.xticks([0, 1, 2, 3])
plt.yticks([0, 10, 20, 30])
plt.show()

# %%
import matplotlib.pyplot as plt
x = [1, 2, 3, 4]
y = [10, 20, 25, 30]
plt.plot(x, y)
plt.title("Sales Over 4 Quarters")
plt.xlabel("Quarter")
plt.ylabel("Sales")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
x = [1, 2, 3, 4]
y = [10, 20, 25, 30]
plt.plot(x, y)
plt.title("Sales Over 4 Quarters")
plt.xlabel("Quarter")
plt.ylabel("Sales")
plt.grid(True)
plt.savefig("sales_chart.png")
