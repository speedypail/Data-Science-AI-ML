# %%
# Raw data
ages = [20, 30, 40, 50]

print(ages)
# Out:
# [20, 30, 40, 50]

# %%
from sklearn.preprocessing import MinMaxScaler

data = [[1000], [2000], [3000], [4000]]

scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(data)

print(scaled_data)
# Out:
# [[0.        ]
#  [0.33333333]
#  [0.66666667]
#  [1.        ]]

# %%
from sklearn.preprocessing import MinMaxScaler

data = [[10], [20], [30], [40]]

scaler = MinMaxScaler()
normalized = scaler.fit_transform(data)

print(normalized)
# Out:
# [[0.        ]
#  [0.33333333]
#  [0.66666667]
#  [1.        ]]

# %%
from sklearn.preprocessing import StandardScaler

data = [[10], [20], [30], [40]]

scaler = StandardScaler()
standardized = scaler.fit_transform(data)

print(standardized)
# Out:
# [[-1.34164079]
#  [-0.4472136 ]
#  [ 0.4472136 ]
#  [ 1.34164079]]

# %%
import matplotlib.pyplot as plt

data = [1, 2, 2, 3, 3, 3, 10]

plt.hist(data)
plt.show()

# %%
# Wrong: using same data for training and testing
data = [100, 200, 300, 400]

train = data
test = data

print("This causes data leakage")
# Out:
# This causes data leakage

# %%
# Biased sample
sample = ["rich", "rich", "rich"]

print(sample)
# Out:
# ['rich', 'rich', 'rich']

# %%
# Showing only high values
scores = [90, 92, 95]

print(scores)
# Out:
# [90, 92, 95]

# %%
ice_cream_sales = [10, 20, 30]
drowning_cases = [1, 2, 3]

print(ice_cream_sales, drowning_cases)
# Out:
# [10, 20, 30] [1, 2, 3]

# %%
# Group data
group_A = [90, 80]
group_B = [70, 60]

combined = group_A + group_B

print(combined)
# Out:
# [90, 80, 70, 60]

# %%
probability_of_rain = 0.7

print(probability_of_rain)
# Out:
# 0.7
