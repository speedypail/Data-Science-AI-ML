# %%
import pandas as pd
data = {'Name': ['Alice', 'Bob', 'Charlie'], 'Age': [24, 25, 23], 'Marks': [85, 90, 78]}
df = pd.DataFrame(data)
print(df['Name'])
print(df[['Name', 'Marks']])
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# Name: Name, dtype: object
#       Name  Marks
# 0    Alice     85
# 1      Bob     90
# 2  Charlie     78

# %%
import pandas as pd
data = {'Name': ['Alice', 'Bob', 'Charlie'], 'Age': [24, 25, 23], 'Marks': [85, 90, 78]}
df = pd.DataFrame(data)
print(df.loc[0])
# print(df.loc[0, 'Marks'])
# print(df.loc[:, ['Name', 'Marks']])
# Out:
# Name     Alice
# Age         24
# Marks       85
# Name: 0, dtype: object

# %%
import pandas as pd
data = {'Name': ['Alice', 'Bob', 'Charlie'], 'Age': [24, 25, 23], 'Marks': [85, 90, 78]}
df = pd.DataFrame(data)
# print(df)
print(df.iloc[1])
print(df.iloc[1, 2])
# Out:
# Name     Bob
# Age       25
# Marks     90
# Name: 1, dtype: object
# 90

# %%
import pandas as pd
df = pd.DataFrame({
    "A": [1, 2],
    "B": [3, 4]
})
df = df.applymap(lambda x: x * 10)
print(df)
# Out:
#     A   B
# 0  10  30
# 1  20  40
# C:\Users\Hp\AppData\Local\Temp\ipykernel_14008\1303122048.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x * 10)
