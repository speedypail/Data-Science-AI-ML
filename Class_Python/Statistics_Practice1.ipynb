# %%
marks = [60, 70, 80, 90]

average = sum(marks) / len(marks)
print(average)
# Out:
# 75.0

# %%
temperature = [30, 32, 35, 31]

print(temperature)
# Out:
# [30, 32, 35, 31]

# %%
dataset = [
    [25, 30000],
    [30, 40000],
    [22, 25000]
]

print(dataset)
# Out:
# [[25, 30000], [30, 40000], [22, 25000]]

# %%
temperatures = [30.1, 30.5, 29.9, 30.3]

print(temperatures)
# Out:
# [30.1, 30.5, 29.9, 30.3]

# %%
ages = [25, 30, None, 28]

print(ages)
# Out:
# [25, 30, None, 28]

# %%
ages = [20, 25, 30, 35] 
heights = [150.5, 160.2, 170.8]

avg_age = sum(ages) / len(ages)
max_height = max(heights)

print("Average Age:", avg_age)
print("Maximum Height:", max_height)
# Out:
# Average Age: 27.5
# Maximum Height: 170.8

# %%
students = [10, 20, 30]

total_students = sum(students)

print("Total Students:", total_students)
# Out:
# Total Students: 60

# %%
temperature = [36.5, 37.2, 38.1]

avg_temp = sum(temperature) / len(temperature)
min_temp = min(temperature)
max_temp = max(temperature)

print("Average Temperature:", avg_temp)
print("Min Temperature:", min_temp)
print("Max Temperature:", max_temp)
# Out:
# Average Temperature: 37.26666666666667
# Min Temperature: 36.5
# Max Temperature: 38.1

# %%
colors = ["Red", "Blue", "Green"]

unique_colors = set(colors)

print("Categories:", unique_colors)
# Out:
# Categories: {'Blue', 'Red', 'Green'}

# %%
gender = ["Male", "Female", "Other"]

unique_values = set(gender)

print("Categories:", unique_values)
# Out:
# Categories: {'Other', 'Female', 'Male'}

# %%
ratings = ["Low", "Medium", "High"]

order = {"Low": 1, "Medium": 2, "High": 3}

numeric_ratings = [order[r] for r in ratings]

print("Ordered Ratings:", numeric_ratings)
# Out:
# Ordered Ratings: [1, 2, 3]
