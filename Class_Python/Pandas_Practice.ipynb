# %%
import pandas as pd
data=pd.Series([10,20,30,40])
print(data)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
df=pd.DataFrame({'Name':['Alice','Bob'],'Age':[20,25]})
print(df)
# Out:
#     Name  Age
# 0  Alice   20
# 1    Bob   25

# %%
print(df.describe())
# Out:
#              Age
# count   2.000000
# mean   22.500000
# std     3.535534
# min    20.000000
# 25%    21.250000
# 50%    22.500000
# 75%    23.750000
# max    25.000000

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.3.3

# %%
a=[1,2,3]
s=pd.Series(a)
print(s[2])
# Out:
# 3

# %%
a=[1,2,3]
s=pd.Series(a,name="age")
print(s)
# Out:
# 0    1
# 1    2
# 2    3
# Name: age, dtype: int64

# %%
a=[1,2,3]
s=pd.Series(a,index=["x","y","z"])
print(s)
# Out:
# x    1
# y    2
# z    3
# dtype: int64

# %%
a=[1,2,3]
s=pd.Series(a,index=["x","y","z"])
print(s["x"])
# Out:
# 1

# %%
marks={"maths":50,"eng":30}
s=pd.Series(marks)
print(s)
# Out:
# maths    50
# eng      30
# dtype: int64

# %%
data={"name":["alin","roshni","appu"],
      "age":[20,21,20],
     "mark":[100,200,300]}
df=pd.DataFrame(data)
print(df[["name","age"]])
# Out:
#      name  age
# 0    alin   20
# 1  roshni   21
# 2    appu   20
