# %%
print("Hello World ")
# Out:
# Hello World

# %%
myVariable = "Hello"  # initializes myVariable with "Hello"
myVariable = "World"  # reassigns myVariable to "World"
print(myVariable)
# Out:
# World

# %%
# Assigning values to two variables in a single line
x, y = 10, 20
print(x,y)
# Out:
# 10 20

# %%
# Assigning a single value to multiple variables
x = y = z = 0
print(x,y,z)
# Out:
# 0 0 0

# %%
# Outputting the value of a variable
x = 10
print(x)  # Output: 10
# Out:
# 10

# %%
x = 5
print(type(x))  # Output: <class 'int'>

message = "Hello"
print(type(message))  # Output: <class 'str'>
# Out:
# <class 'int'>
# <class 'str'>

# %%
a = 10
b = 2.5
result = a + b
print(result)
# Out:
# 12.5

# %%
x = "50"
y = int(x)
print(y)
# Out:
# 50

# %%
x = 5.6  # float variable
y = int(x)  # convert float to integer
print(y)  # Output: 5
# Out:
# 5

# %%
x = "3.14"  # string variable
y = float(x)  # convert string to float
print(y)  # Output: 3.14
z=int(y)
print(z)
# Out:
# 3.14
# 3

# %%
x = 42  # integer variable
y = str(x)  # convert integer to string
print("The answer is " + y)  # Output: The answer is 42
# Out:
# The answer is 42

# %%
price = "200"
quantity = "4"
total = int(price) * int(quantity)
print(total)
# Out:
# 800
