# %%
marks=[60,70,80,90]
mean=sum(marks)/len(marks)
print(mean)
# Out:
# 75.0

# %%
import statistics as st
data=[10,50,30,20,40]
data.sort()
median=st.median(data)
print(median)
# Out:
# 30

# %%
import statistics

data = [1, 2, 2, 3, 4, 2, 5]

mode = statistics.mode(data)
print("Mode:", mode)
# Out:
# Mode: 2

# %%
data = [10, 20, 30, 40, 1000]

mean = sum(data) / len(data)

import statistics
median = statistics.median(data)

print("Mean:", mean)
print("Median:", median)
# Out:
# Mean: 220.0
# Median: 30

# %%
import numpy as np

data = [2, 4, 6, 8]

variance = np.var(data)
print("Variance:", variance)
# Out:
# Variance: 5.0

# %%
import numpy as np

data = [2, 4, 6, 8]

std_dev = np.std(data)
print("Standard Deviation:", std_dev)
# Out:
# Standard Deviation: 2.23606797749979

# %%
import numpy as np

data1 = [10, 10, 10, 10]
data2 = [5, 10, 15, 20]

print("Variance 1:", np.var(data1))
print("Variance 2:", np.var(data2))
# Out:
# Variance 1: 0.0
# Variance 2: 31.25

# %%
data = [2, 4, 6]

mean = sum(data) / len(data)

differences = [(x - mean) for x in data]
squared = [(x - mean)**2 for x in data]

print("Differences:", differences)
print("Squared Differences:", squared)
# Out:
# Differences: [-2.0, 0.0, 2.0]
# Squared Differences: [4.0, 0.0, 4.0]

# %%
favorable = 1   # getting Head
total = 2       # Head or Tail

probability = favorable / total
print(probability)
# Out:
# 0.5

# %%
# Dice roll outcomes
outcomes = [1, 2, 3, 4, 5, 6]

# Event: even numbers
event = [2, 4, 6]

probability = len(event) / len(outcomes)
print(probability)
# Out:
# 0.5

# %%
# Check possible events
dice = [1, 2, 3, 4, 5, 6]

# Impossible event
print(7 in dice)

# Certain event
print(3 in dice)
# Out:
# False
# True

# %%
import random

result = random.choice(["Head", "Tail"])
print(result)
# Out:
# Head
