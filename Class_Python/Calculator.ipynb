# %%
a=int(input("Enter the value of a "))
b=int(input("Enter the value of b "))
print("The addition of a and b is ",a+b)
print("The difference of a and b is ",a-b)
print("The product of a and b is ",a*b)
print("The division of a and b is ",a/b)
print("The reminder of a and b is", a%b)
print("The exponent of a and b is", a**b)
print("The floor division of a and b is", a//b)
# Out:
# Enter the value of a  29
# Enter the value of b  4
# The addition of a and b is  33
# The difference of a and b is  25
# The product of a and b is  116
# The division of a and b is  7.25
# The reminder of a and b is 1
# The exponent of a and b is 707281
# The floor division of a and b is 7
