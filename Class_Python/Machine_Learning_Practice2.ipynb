# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.7.2

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 from sklearn.model_selection import train_test_split
# ----> 2 X_train, X_test, y_train, y_test = train_test_split(X, y)
#
# NameError: name 'X' is not defined

# %%
model = SomeModel()
model.fit(X_train, y_train)
predictions = model.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 model = SomeModel()
#       2 model.fit(X_train, y_train)
#       3 predictions = model.predict(X_test)
#
# NameError: name 'SomeModel' is not defined

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression

pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('model', LinearRegression())
])

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

texts = ["good product", "bad quality", "good quality"]
vectorizer = TfidfVectorizer()
X_features = vectorizer.fit_transform(texts)

print(X_features.toarray())
print(vectorizer.get_feature_names_out())
# Out:
# [[0.         0.60534851 0.79596054 0.        ]
#  [0.79596054 0.         0.         0.60534851]
#  [0.         0.70710678 0.         0.70710678]]
# ['bad' 'good' 'product' 'quality']

# %%
from sklearn.model_selection import train_test_split

X = [[10], [20], [30], [40], [50]]
y = [100, 200, 300, 400, 500]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

print("X_train:", X_train)
print("X_test:", X_test)
print("y_train:", y_train)
print("y_test:", y_test)
# Out:
# X_train: [[30], [20], [50], [10]]
# X_test: [[40]]
# y_train: [300, 200, 500, 100]
# y_test: [400]

# %%
actual_values = [0, 0, 1, 0, 0, 1]

most_common_value = max(set(actual_values), key=actual_values.count)

predictions = [most_common_value] * len(actual_values)

print("Actual values:", actual_values)
print("Baseline predictions:", predictions)
# Out:
# Actual values: [0, 0, 1, 0, 0, 1]
# Baseline predictions: [0, 0, 0, 0, 0, 0]

# %%
data = [
    [2, 6, 40],
    [4, 7, 60],
    [6, 8, 75],
    [8, 8, 90]
]

# Columns: Hours Studied, Sleep Hours, Marks

# %%
X = [
    [2, 6],
    [4, 7],
    [6, 8],
    [8, 8]
]

y = [40, 60, 75, 90]

# %%
X_train = X[:3]
X_test = X[3:]

y_train = y[:3]
y_test = y[3:]

# %%
# Example feature values before scaling
X_train = [
    [2, 6],
    [4, 7],
    [6, 8]
]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)

print("Before scaling:", X_train)
print("After scaling:", X_train_scaled)
# Out:
# Before scaling: [[2, 6], [4, 7], [6, 8]]
# After scaling: [[-1.22474487 -1.22474487]
#  [ 0.          0.        ]
#  [ 1.22474487  1.22474487]]

# %%
baseline_prediction = sum(y_train) / len(y_train)

baseline_predictions = [baseline_prediction] * len(y_test)

print("Baseline prediction:", baseline_predictions)
# Out:
# Baseline prediction: [58.333333333333336]
