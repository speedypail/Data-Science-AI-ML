# %%
import numpy as np

A = np.array([[1, 2],
              [3, 4]])

B = np.array([[5, 6],
              [7, 8]])

result = np.dot(A, B)
print(result)
# Out:
# [[19 22]
#  [43 50]]

# %%
import numpy as np

A = np.array([[1, 2, 3]])   # shape (1, 3)
B = np.array([[4], [5], [6]])  # shape (3, 1)
result=A.shape
print(result)
result2=B.shape
print(result2)
# Out:
# (1, 3)
# (3, 1)

# %%
import numpy as np

x = np.array([1, 2, 3, 4])
y = x**2

dy_dx = np.gradient(y, x)
print(dy_dx)
# Out:
# [3. 4. 6. 7.]

# %%
# Example: derivative of y = x^2 at x = 3
x = 3
slope = 2 * x
print(slope)
# Out:
# 6

# %%
# Example: derivative of y = x^2 at x = 3
x = 3
slope = 2 * x
print(slope)
# Out:
# 6

# %%
import numpy as np

x = np.array([1, 2, 3, 4])
y = x**2

area = np.trapz(y, x)
print(area)
# Out:
# 21.5
# C:\Users\Hp\AppData\Local\Temp\ipykernel_12100\1662675505.py:6: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   area = np.trapz(y, x)
