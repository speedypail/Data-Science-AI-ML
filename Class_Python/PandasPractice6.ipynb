# %%
import pandas as pd
data=pd.Series([1,2,3,4,5])
df=pd.DataFrame(data)
df.to_csv("output.csv", index=False, encoding="utf-8")
print(df)
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %%
df.to_excel("report.xlsx", sheet_name="Summary", index=False)

# %%
print(df)
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %%
print(df.dtypes)
# Out:
# 0    int64
# dtype: object

# %%
import os
import pandas as pd

data = {'City': ['New York', 'Paris'], 'Temperature': [22, 18]}
df = pd.DataFrame(data)

df.to_json('weather.json')

file_path = os.path.abspath('weather.json')
print(f"File saved at: {file_path}")
# Out:
# File saved at: E:\Vaibhav\Data_Science_AIML\Class_Python\weather.json
