# %%
import seaborn as sns
import matplotlib.pyplot as plt

tips = sns.load_dataset("tips")
g = sns.FacetGrid(tips, col="time")
g.map(sns.histplot, "total_bill")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

tips = sns.load_dataset("tips")
sns.catplot(data=tips, x="day", y="total_bill", hue="sex", kind="box")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

iris = sns.load_dataset("iris")
sns.pairplot(iris, hue="species")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

tips = sns.load_dataset("tips")
sns.relplot(data=tips, x="total_bill", y="tip", row="sex", col="time", hue="smoker")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

tips = sns.load_dataset("tips")
sns.scatterplot(data=tips, x="total_bill", y="tip")

plt.title("Relationship between Total Bill and Tip")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

tips = sns.load_dataset("tips")
sns.scatterplot(data=tips, x="total_bill", y="tip")

plt.xlabel("Total Bill Amount ($)")
plt.ylabel("Tip Amount ($)")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

tips = sns.load_dataset("tips")
sns.countplot(data=tips, x="day")

plt.xticks(rotation=45)
plt.yticks(fontsize=12)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.barplot(data=sns.load_dataset("tips"), x="day", y="total_bill")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

tips = sns.load_dataset("tips")
sns.scatterplot(data=tips, x="total_bill", y="tip")

max_tip = tips['tip'].max()
max_row = tips[tips['tip'] == max_tip].iloc[0]

plt.annotate(
    "Highest Tip",
    xy=(max_row["total_bill"], max_row["tip"]),
    xytext=(max_row["total_bill"] + 5, max_row["tip"] + 1),
    arrowprops={"arrowstyle": "->"}
)

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

tips = sns.load_dataset("tips")
sns.boxplot(data=tips, x="day", y="total_bill")

plt.title("Total Bill Distribution by Day")
plt.xlabel("Day of the Week")
plt.ylabel("Total Bill")
plt.grid(True, linestyle="--", alpha=0.6)
plt.show()
