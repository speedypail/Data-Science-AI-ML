# %%
import numpy as np

person = np.array([170, 65, 20])
print(person)
# Out:
# [170  65  20]

# %%
import numpy as np

point = np.array([3, 4])
print("X:", point[0], "Y:", point[1])
# Out:
# X: 3 Y: 4

# %%
import numpy as np

v1 = np.array([1, 2])
v2 = np.array([3, 4])

result = v1 + v2
print(result)
# Out:
# [4 6]

# %%
import numpy as np

v = np.array([2, 4, 6])

result = 3 * v
print(result)
# Out:
# [ 6 12 18]

# %%
import numpy as np

v = np.array([3, 4])

magnitude = np.linalg.norm(v)
print(magnitude)
# Out:
# 5.0
