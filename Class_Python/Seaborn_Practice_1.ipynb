# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(data=sns.load_dataset("tips"), x="total_bill")
print(tips.head())
plt.show()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
import seaborn as sns
import matplotlib.pyplot as plt

tips = sns.load_dataset("tips")
sns.boxplot(data=tips, x="day", y="total_bill")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.lineplot(data=sns.load_dataset("fmri"), x="timepoint", y="signal")
print(fmri.head())
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 5
#       2 import matplotlib.pyplot as plt
#       4 sns.lineplot(data=sns.load_dataset("fmri"), x="timepoint", y="signal")
# ----> 5 print(fmri.head())
#       6 plt.show()
#
# NameError: name 'fmri' is not defined

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_palette("pastel")
sns.countplot(data=sns.load_dataset("tips"), x="day")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

tips = sns.load_dataset("tips")
sns.violinplot(data=tips, x="sex", y="total_bill")
plt.show()

# %%
import seaborn as sns

# Load a built-in dataset
tips = sns.load_dataset("tips")

# Display first few rows
print(tips.head())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
import seaborn as sns
import matplotlib.pyplot as plt 

# Load dataset
penguins = sns.load_dataset("penguins")

# Create a new DataFrame column
penguins['body_ratio'] = penguins['body_mass_g'] / penguins['flipper_length_mm']

# Plot using DataFrame columns
sns.scatterplot(data=penguins, x="flipper_length_mm", y="body_mass_g")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt 

tips = sns.load_dataset("tips")

# Plot a categorical vs numerical variable
sns.boxplot(data=tips, x="day", y="total_bill")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt 

sns.relplot(data=sns.load_dataset("tips"),
            x="total_bill", y="tip")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt 

plt.figure()
sns.scatterplot(data=sns.load_dataset("tips"),
                x="total_bill", y="tip")
plt.show()

# %%
fmri = sns.load_dataset("fmri")

# Display first few rows
print(fmri.head())
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.lineplot(data=sns.load_dataset("fmri"), x="timepoint", y="signal")
print(fmri.head())
plt.show()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970
