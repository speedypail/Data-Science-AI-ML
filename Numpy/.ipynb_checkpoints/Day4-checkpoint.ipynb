# %%
# Task 1
import numpy as np
marks=np.array([35, 55, 75, 40, 90])
result=np.where(marks>=40,'Pass','Fail')
print(f"The result of the students are: {result}")
# Out:
# The result of the students are: ['Fail' 'Pass' 'Pass' 'Pass' 'Pass']

# %%
# Task 2
condition=(arr<40,arr<60,arr<80)
choice=("Fail","C","B")
result2=np.select(condition,choice,default='A')
print(result2)
# Out:
# ['Fail' 'C' 'B' 'C' 'A']

# %%
# Task 3
arr=np.array([50, 60, 50, 70, 60, 80])
unique=np.unique(arr)
print(f"The unique elements in the array is:{unique}")
# Out:
# The unique elements in the array is:[50 60 70 80]

# %%
# Task 4
print(np.any(marks<40))
# Out:
# True

# %%
# Task 5
print(np.all(marks>=40))
# Out:
# False
