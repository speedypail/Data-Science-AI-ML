# %%
import matplotlib.pyplot as plt
import numpy as np
x=[1,2,3,4,5]
y=[100,150,np.nan,200,250]
plt.plot(days,sales)
plt.annotate("Highest Sale",xy=(5,250),xytext=(4,200),arrowprops=dict(arrowstyle='->'))
plt.title('Daily Sales Report')
plt.xlabel('Days')
plt.ylabel('Sales Amount')
plt.show()
