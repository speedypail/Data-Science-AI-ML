# %%
unit_price=500
quantity_sold=4
sales_target=10
total_sales=unit_price*quantity_sold
print("The total sales is ", total_sales)
additional_sales=20
additional_sales+=quantity_sold
print("The additional sales is ", additional_sales)
print("To check wheather the total sales is greater than or equal to target sales ",total_sales>=sales_target)
sales_check=(total_sales>=sales_target) and (quantity_sold>0)
print("Is sales target met and quantity>0 ?",sales_check)
# Out:
# The total sales is  2000
# The additional sales is  24
# To check wheather the total sales is greater than or equal to target sales  True
# Is sales target met and quantity>0 ? True
