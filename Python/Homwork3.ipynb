# %%
user_bio="""
Hi, I am Anjali.
I love Python programming.
Improving my programming skills is my goal.
"""
print(f"The user bio is: {user_bio}")
print(f"The total number of charcter is:{len(user_bio)}")
print(f"Unwanted spaces to be removed from user_bio: {user_bio.strip()}")
lines=user_bio.split("\n")
print(f"Number of lines in user_bio:{len(lines)}")
# Out:
# The user bio is:
# Hi, I am Anjali.
# I love Python programming.
# Improving my programming skills is my goal.
#
# The total number of charcter is:89
# Unwanted spaces to be removed from user_bio: Hi, I am Anjali.
# I love Python programming.
# Improving my programming skills is my goal.
# Number of lines in user_bio:5
