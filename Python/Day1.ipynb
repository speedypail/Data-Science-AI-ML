# %%
student_name="Vaibhav "
print("The name of the student is ",student_name)
print("The data type of student is",type(student_name))
student_age=22
print("The student age is ",student_age)
print("The data type of student_age is",type(student_age))
student_age=23
print("The updated age is ",student_age)
book_price,book_quantity="200","4"
total_price=int(book_price)*int(book_quantity)
print("The total price of the item is ",total_price)
is_enrolled=True
print(is_enrolled)
print("The data type of is_enrolled",type(is_enrolled))
# Out:
# The name of the student is  Vaibhav
# The data type of student is <class 'str'>
# The student age is  22
# The data type of student_age is <class 'int'>
# The updated age is  23
# The total price of the item is  800
# True
# The data type of is_enrolled <class 'bool'>
