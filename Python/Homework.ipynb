# %%
product_name="Iphone 17 "
product_price="154321.25"
product_quantity="1"
discount_percentage=20
a=float(product_price)
b=int(product_quantity)
total_amount=a*b
discount_amount=30864.25
final_amount=total_amount-discount_amount
tax=service_charge=0
print("The name of the product is ", product_name)
print("The discount percentage is ", discount_percentage,"%")
print("The price of the product is Rs", a )
print("The product quantity is ",b)
print("The total_amount is Rs", total_amount)
print("The final amount after discount is Rs",final_amount)
print("The tax is", tax, "\nThe service charge is", service_charge)
print("The data type of final amount is ",type(final_amount))
# Out:
# The name of the product is  Iphone 17
# The discount percentage is  20 %
# The price of the product is Rs 154321.25
# The product quantity is  1
# The total_amount is Rs 154321.25
# The final amount after discount is Rs 123457.0
# The tax is 0
# The service charge is 0
# The data type of final amount is  <class 'float'>
