# %%
import numpy as np
x = np.array([1, 2, 3, 4, 5, 6])
y = x**2
dy_dx=np.gradient(y,x)
print(dy_dx)
# Out:
# [ 3.  4.  6.  8. 10. 11.]

# %%
print(dy_dx[2])
# Out:
# 6.0

# %%
print(np.max(dy_dx))
# Out:
# 11.0

# %%
print(np.min(dy_dx))
# Out:
# 3.0

# %%
area=np.trapz(y,x)
print(area)
# Out:
# 72.5
# C:\Users\Hp\AppData\Local\Temp\ipykernel_21024\938124735.py:1: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   area=np.trapz(y,x)
