# %%
import numpy as np
X = np.array([[2, 1, 3], [4, 2, 1], [1, 5, 2]])
W = np.array([[1, 2], [3, 1],[2, 4]])
shape1=X.shape
print(shape1)
shape2=W.shape
print(shape2)
# Out:
# (3, 3)
# (3, 2)

# %%
prediction=np.dot(X,W)
print(prediction)
# Out:
# [[11 17]
#  [12 14]
#  [20 15]]

# %%
print(np.max(prediction))
# Out:
# 20

# %%
print(np.min(prediction))
# Out:
# 11

# %%
print(np.sum(prediction))
# Out:
# 89

# %%
print(np.size(prediction))
# Out:
# 6
