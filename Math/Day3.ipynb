# %%
import numpy as np
person=np.array([170,65,20])
print(person)
# Out:
# [170  65  20]

# %%
print('Height:', person[0],'Weight:', person[1], 'Age:', person[2])
# Out:
# Height: 170 Weight: 65 Age: 20

# %%
v1=3*person
print(v1)
# Out:
# [510 195  60]

# %%
v2=2*person
print(v2)
# Out:
# [340 130  40]

# %%
mag=np.linalg.norm(person)
print(mag)
# Out:
# 183.09833423600554

# %%
features=len(person)
print(features)
# Out:
# 3

# %%
person2=np.array([160,55,18])
add=person+person2
print(add)
# Out:
# [330 120  38]
