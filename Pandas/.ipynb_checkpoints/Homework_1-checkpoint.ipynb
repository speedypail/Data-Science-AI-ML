# %%
# Part A
import pandas as pd
subjects=['Maths','Science','English','Computer']
marks=[85,78,90,88]
student_marks=pd.Series(marks,subjects)
print(series)
maximum=series.max()
print(f"The highest marks is: {maximum}")
minimum=series.min()
print(f"The lowest marks is: {minimum}")
total=series.sum()
print(f"The total marks is: {total}")
average=series.mean()
print(f"The average marks is: {average}")
# Out:
# Maths       85
# Science     78
# English     90
# Computer    88
# dtype: int64
# The highest marks is: 90
# The lowest marks is: 78
# The total marks is: 341
# The average marks is: 85.25

# %%
# Part B
marks_df={'Name':['Arun','Binu','Chitra'],
          'Math': [85, 70, 92],
          'Science':[78, 82, 88],
          'English': [90, 76, 95],
          'Computer': [88, 80, 91]
         }
df=pd.DataFrame(marks_df)
df['Total']=df['Math']+df['Science']+df['English']+df['Computer']
df['Average']=df['Total']/4
print(df)
# Out:
#      Name  Math  Science  English  Computer  Total  Average
# 0    Arun    85       78       90        88    341    85.25
# 1    Binu    70       82       76        80    308    77.00
# 2  Chitra    92       88       95        91    366    91.50

# %%
# Part C
print(type(student_marks))
# Out:
# <class 'pandas.core.series.Series'>

# %%
print(type(marks_df))
# Out:
# <class 'dict'>
