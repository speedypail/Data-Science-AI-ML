# %%
# Task 1
import pandas as pd
data={"Name":["Vaibhav"],"Age":[25],"City":["Trivandrum"]}
df=pd.DataFrame(data,index=[1])
print(df)
# Out:
#       Name  Age        City
# 1  Vaibhav   25  Trivandrum

# %%
# Task 2
df_dict={
    "Name":["Asha","Ravi","Meera"],
    "Age":[24,30,26],
    "Dept":["HR","IT","Finance"]
}
df=pd.DataFrame(df_dict,index=[1,2,3])
print(df)
# Out:
#     Name  Age     Dept
# 1   Asha   24       HR
# 2   Ravi   30       IT
# 3  Meera   26  Finance

# %%
# Task 3
student=pd.read_csv("student.csv")
df2=pd.DataFrame(student)
print(df2)
# Out:
#       Name  Age Grade  Subject
# 0    Alice   20     A     Math
# 1      Bob   21     B  Science
# 2  Charlie   22     A  English

# %%
# Task 4
import openpyxl
employees=pd.read_excel("employees.xlsx")
df3=pd.DataFrame(employees)
print(df3)
# Out:
#     Name  Age                Department  Salary
# 0   Asha   24                        HR   35000
# 1   Ravi   30                        IT   50000
# 2  Meera   26                   Finance   40000

# %%
# Task 4
data=pd.read_json("data.json")
df4=pd.DataFrame(data)
print(df4)
# Out:
#    Name  Age Grade
# 0  Arun   22     A
# 1  Binu   21     B
