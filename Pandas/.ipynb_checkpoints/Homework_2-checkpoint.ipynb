# %%
# Task 1
import pandas as pd
data = [
    ["Ammu", 23, "Python"],
    ["manu", 25, "Django"],
    ["Anu", 22, "React"]
]
df=pd.DataFrame(data,columns=['Name','Age','Course'],index=['S1','S2','S3'])
print(df)
# Out:
#     Name  Age  Course
# S1  Ammu   23  Python
# S2  manu   25  Django
# S3   Anu   22   React

# %%
# Task 2
df_tuples= [
    ("Pen", 10),
    ("Book", 50),
    ("Bag", 700)
]
df2=pd.DataFrame(df_tuples,columns=['Item','Price'])
print(df2)
# Out:
#    Item  Price
# 0   Pen     10
# 1  Book     50
# 2   Bag    700

# %%
# Task 3
marks=pd.read_csv("marks.txt",sep='|',header=None,names=['ID','Name','Mark'])
print(marks)
# Out:
#    ID    Name  Mark
# 0   1    Arun    85
# 1   2    Binu    78
# 2   3  Chitra    92

# %%
# Task 4
import openpyxl
employees=pd.read_excel('employees.xlsx')
df=employees[['Name','Salary']]
print(df)
# Out:
#     Name  Salary
# 0   Asha   35000
# 1   Ravi   50000
# 2  Meera   40000

# %%
# Task 5
students=pd.read_json('data.json')
df2=students[students['Grade']=='A']
print(df2)
# Out:
#    Name  Age Grade
# 0  Arun   22     A

# %%
# Task 6
import sqlite3
conn = sqlite3.connect("school.db")
with open("students.sql", "r") as file:
    sql_script=file.read()
conn.executescript(sql_script)
df=pd.read_sql("SELECT * FROM students", conn)
print(df)
conn.close()
# Out:
#    ID    Name  Mark
# 0   1    Arun    85
# 1   2    Binu    78
# 2   3  Chitra    92
