# %%
import pandas as pd
import random

products = ["Laptop", "Mouse", "Keyboard", "Monitor", "Printer", "Tablet", "Phone"]
categories = ["Electronics", "Accessories", "Office"]

rows = []

for i in range(1, 501):
    rows.append({
        "order_id": i,
        "product": random.choice(products),
        "category": random.choice(categories),
        "price": round(random.uniform(100, 50000), 2),
        "quantity": random.randint(1, 10)
    })

# Create DataFrame
sales_df = pd.DataFrame(rows)

# Save as CSV
sales_df.to_csv("sales_data.csv", index=False)

print("sales_data.csv created successfully")
print(sales_df.head())
print(sales_df.shape)
# Out:
# sales_data.csv created successfully
#    order_id  product     category     price  quantity
# 0         1  Monitor  Electronics  14059.10         8
# 1         2   Tablet  Electronics  34754.25         2
# 2         3  Printer  Electronics  27637.54         1
# 3         4   Laptop  Accessories  32664.25         9
# 4         5   Tablet       Office  34658.38         8
# (500, 5)
